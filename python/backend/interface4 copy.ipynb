# %%
import pandas as pd
import numpy
import select_file
import clean_data
import result
import diagramme_camembert

# %%
paths = ["./fot10_copie.xlsx","./fot12_copie.xlsx"]

liste_df = select_file.select_file(paths)
liste_dc = clean_data.clean_data(liste_df)
liste_ds = result.filter_conformity(liste_dc)

liste_variables = result.compare_reports(liste_ds)

diagramme_camembert.afficher_diagramme(liste_variables)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /Users/lukapavageau/Library/Mobile Documents/com~apple~CloudDocs/QIF 4A/semestre 8/projetEntreprise/python/DEVILLE-Dashboard/python/backend/result.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == row[1]:
# /Users/lukapavageau/Library/Mobile Documents/com~apple~CloudDocs/QIF 4A/semestre 8/projetEntreprise/python/DEVILLE-Dashboard/python/backend/result.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if pd.notna(row[0]):  # Vérifie que la valeur n'est pas NaN
# /Users/lukapavageau/Library/Mobile Documents/com~apple~CloudDocs/QIF 4A/semestre 8/projetEntreprise/python/DEVILLE-Dashboard/python/backend/result.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif pd.isna(row[1]):  # Premier cas : valeur dans la première colonne, NaN dans la seconde
# /Users/lukapavageau/Library/Mobile Documents/com~apple~CloudDocs/QIF 4A/semestre 8/projetEntreprise/python/DEVILLE-Dashboard/python/backend/result.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif pd.isna(row[0]):  # Deuxième cas : NaN dans la première colonne, valeur dans la seconde
